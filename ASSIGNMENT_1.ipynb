# %% [markdown]
# <a href="https://colab.research.google.com/github/Tchalz/delete_now/blob/master/ASSIGNMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SECTION 1: Libraries

# %% [markdown]
# #####QUESTION 1(ANSWERS)

# %% [markdown]
# In Programming, a library consists of code modules pre-installed, that help perform frequent operations efficiently, reducing the need to code from scratch.

# %% [markdown]
# #####QUESTION 2(ANSWERS)

# %% [markdown]
# a).NumPy:
# is used for
# Fast numerical calculations
#
# b).Panadas:
#  is used for working with tables(dataframes) and data analysis

# %% [markdown]
# #SECTION 2: NUMPY

# %% [markdown]
# #####QUESTION 3(ANSWERS)

# %%
import pandas as pd

# %%
import numpy as np

# %%
first_list = [100, 30, 25, 20, 5, 15]

# %%
print(np.array([first_list]))
# Out:
# [[100  30  25  20   5  15]]

# %% [markdown]
# #SECTION 3: PANDAS - BUILDING AND EXPLORING A DATASET

# %%
import pandas as pd

# %% [markdown]
#  ##### STEP 1

# %%
data = {"StudentID": ["TC001","TC002","TC003","TC004","TC005","TC006","TC007","TC008","TC009","TC010","TC011","TC012","TC013","TC014","TC015","TC016","TC017","TC018","TC019","TC020"],
        "Name": ["Chinedu Odoh","Chiamaka Okafor","Ifeanyi Igwe","Obinna Magnus","Ngozi Okeke","Chukwuemeka Ani","Nnamdi Ibeh","Amarachi Ndah","Kelechi Nwosu","Uche Ndukwe", "Chizoba A","Ifeoma","Somtochukwu","Chisom","Nkiru","Obiageli","Chidinma","Ogechi","Ebuka", "Nwabali Eze"],
        "Age": [21, 21, 22, 22, 20, 23, 21, None, 21, 24, 22, 20, 24, 23, None, 22, 22, 24, 22, 23],
        "Department": ["Theater arts", None, "Political science", "Accounting", "Accounting", "Theater arts", "Mechanical eng", "Theater arts", "Political science", "Theater arts", "Electrical eng", "Electrical eng", "Theater arts", "Electrical eng", "Political science", "Accounting", "Mechanical eng", "Mechanical eng", "Accounting", "Accounting"],
        "Score": [50, 90, 65, 53, 81, None, 85, 100, 59, 80, 96, 87, None, 84, 74, 55, 74, 60, 50, 85],
        "Grade": ["A", "A", "B", "D", "A", "D", "D", "D", "B", "D", "C", "E", "C", "E", "B", "D", "C", "C", "C", "D"]}

# %% [markdown]
# ##### STEP 2

# %%
dataframe1 = pd.DataFrame(data)

# %%
dataframe1.head(5)
# Out:
#   StudentID             Name   Age         Department  Score Grade
# 0     TC001     Chinedu Odoh  21.0       Theater arts   50.0     A
# 1     TC002  Chiamaka Okafor  21.0               None   90.0     A
# 2     TC003     Ifeanyi Igwe  22.0  Political science   65.0     B
# 3     TC004    Obinna Magnus  22.0         Accounting   53.0     D
# 4     TC005      Ngozi Okeke  20.0         Accounting   81.0     A

# %%
subject_series = dataframe1['Department'].unique()
subject_series
# Out:
# array(['Theater arts', None, 'Political science', 'Accounting',
#        'Mechanical eng', 'Electrical eng'], dtype=object)

# %%
subject_series = dataframe1['Department'].nunique()
subject_series
# Out:
# 5

# %%
dataframe1.tail(3)

# %% [markdown]
# ##### STEP 3

# %%
dataframe1.shape

# %% [markdown]
# The code above returns a Tuple of Dimension; 20 rows, 6 columns

# %% [markdown]
# ##### STEP 4

# %%
dataframe1.info()

# %% [markdown]
# The columns with the missing values are;
#
# Age: 2 missing values
#
# Department: 1 missing value
#
# Score: 2 missing values

# %% [markdown]
# ##### STEP 5

# %% [markdown]
# .unique();
# Returns the distinct values as an array.
#
# .nunique();
# Returns the count of distinct values

# %%
print(dataframe1["Department"].unique())

# %%
print(dataframe1['Grade'].nunique())

# %% [markdown]
# ##### STEP 6

# %% [markdown]
# I find the experience of coding myself and answering coding exercises myself
# very intriquing, these were wishes before now.
